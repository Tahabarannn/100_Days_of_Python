# %%
#unique elements, unordered

# %%
myList = [10,20,30,10,20,30,20,40,10,40]

# %%
len(myList)
# Out:
# 10

# %%
mySet = set(myList)

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
# Tuples

# %%
myTuple = (10, "a", 3.14) #immutability

# %%
type(myTuple)
# Out:
# tuple

# %%
myBoolean = True

# %%
type(myBoolean)
# Out:
# bool
