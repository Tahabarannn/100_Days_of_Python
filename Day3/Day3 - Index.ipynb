# %% [markdown]
# ### **Index**

# %%
myString = "Hello Python!"

# %%
myString[4]
# Out:
# 'o'

# %%
len(myString) -1
# Out:
# 12

# %%
myString[12]
# Out:
# '!'

# %%
myString[-1]
# Out:
# '!'

# %%
barcode = "ABCDE123123982"

# %%
"A" + "B"
# Out:
# 'AB'

# %%
name = "Taha"

# %%
surname = "Baran"

# %%
fullname = name + " " + surname

# %%
print(fullname)
# Out:
# Taha Baran

# %%
100 * "AB"
# Out:
# 'ABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABABAB'

# %%
# slicing, starting index, stopping index, steppings size

# %%
#barcode[starting index:stopping index:stepping size]
# Out:
# 'ABCDE123123982'

# %%
barcode[3::]
# Out:
# 'DE123123982'

# %%
barcode[:3:]
# Out:
# 'ABC'

# %%
barcode[::2]
# Out:
# 'ACE2138'

# %%
barcode[3:5]
# Out:
# 'DE'

# %%
barcode[1:9:2]
# Out:
# 'BD13'

# %%
barcode[::-1]
# Out:
# '289321321EDCBA'
