# %%
myString = "Hello Python"

# %%
myString.split()
# Out:
# ['Hello', 'Python']

# %%
type(myString.split())
# Out:
# list

# %%
# list

# %%
myString
# Out:
# 'Hello Python'

# %%
#myString[1] = "a"

# %%
#Immutable - immutability

# %% [markdown]
# # **List**

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
myList[1]
# Out:
# 20

# %%
type(myList[1])
# Out:
# int

# %%
# mutable - mutability

# %%
len(myList)
# Out:
# 3

# %%
myList[len(myList) - 1]
# Out:
# 30

# %%
myList[-2]
# Out:
# 20

# %%
myList.append(80)

# %%
myList
# Out:
# [10, 20, 30, 80]

# %%
myList.append(1)

# %%
myList
# Out:
# [10, 20, 30, 80, 1]

# %%
myList.count(1)
# Out:
# 1

# %%
myList.index(30)
# Out:
# 2

# %%
myList.insert(2,35)

# %%
myList.pop()
# Out:
# 1

# %%
myList.sort()

# %%
myList
# Out:
# [10, 20, 30, 35, 80]

# %%
x = input("Enter x ")
# Out:
# Enter x 10

# %%
type(x)
# Out:
# str

# %%
mixedlist = [100, "Taha", 3.14]

# %%
myNestedList = [10,20,30,40,"taha",[1,2,3]]

# %%
myNestedList[5][1]
# Out:
# 2
